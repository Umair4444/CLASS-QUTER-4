# %% [markdown]
# # Virtual Environment
# * make different isolated environment for different project
#
# * uv venv my-name (to create uv)
# * .venv/Scripts/activate (to activate virtual environment)
